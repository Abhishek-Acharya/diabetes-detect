# %%
import pandas as pd

# %%
data = pd.read_csv('/home/nbuser/library/Pima_Indian_diabetes.csv')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.600000
# 1          1.0     85.0           66.0           29.0      0.0  26.600000
# 2          8.0    183.0           64.0            0.0      0.0  23.300000
# 3          1.0     89.0           66.0           23.0     94.0  19.179925
# 4          0.0    137.0           40.0           35.0    168.0  43.100000
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0        1
# 1                     0.351  31.0        0
# 2                     0.672  32.0        1
# 3                     0.167  21.0        0
# 4                     2.288  33.0        1

# %%
data.shape
# Out:
# (768, 9)

# %%
import seaborn as sns
# %matplotlib inline
# Out:
# /home/nbuser/anaconda3_420/lib/python3.5/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
sns.pairplot(data, x_vars=['Pregnancies','Glucose','BloodPressure']
             ,y_vars=['Outcome'], size=7,aspect=0.7,kind='reg')
# Out:
# /home/nbuser/anaconda3_420/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(data,x_vars=['SkinThickness','Insulin','BMI'],y_vars=['Outcome'],size =7,aspect=0.7,kind='reg')
# Out:
# /home/nbuser/anaconda3_420/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(data,x_vars=['DiabetesPedigreeFunction','Age'],y_vars=['Outcome'],size =7,aspect=0.7,kind='reg')
# Out:
# /home/nbuser/anaconda3_420/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data.count()
# Out:
# Pregnancies                 742
# Glucose                     752
# BloodPressure               768
# SkinThickness               746
# Insulin                     768
# BMI                         757
# DiabetesPedigreeFunction    768
# Age                         749
# Outcome                     768
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 742 non-null float64
# Glucose                     752 non-null float64
# BloodPressure               768 non-null float64
# SkinThickness               746 non-null float64
# Insulin                     768 non-null float64
# BMI                         757 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         749 non-null float64
# Outcome                     768 non-null int64
# dtypes: float64(8), int64(1)
# memory usage: 54.1 KB

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   742.000000  752.000000     768.000000     746.000000  768.000000
# mean      3.866601  119.966097      68.886078      20.309879   79.799479
# std       3.479971   32.367659      19.427448      15.974523  115.244002
# min      -5.412815    0.000000      -3.496455     -11.945520    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  116.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.000000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  757.000000                768.000000  749.000000  768.000000
# mean    31.711151                  0.471876   33.761336    0.348958
# std      8.544789                  0.331329   12.297409    0.476951
# ...

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
#tells the null values in dataset

# %%
sns.set_style('whitegrid')
sns.countplot(x='Outcome',hue='Pregnancies',data=data,palette='RdBu_r')

# %%
sns.countplot(x='Outcome',hue='Glucose',data=data,palette='RdBu_r')

# %%
sns.countplot(x='Outcome',hue='DiabetesPedigreeFunction',data=data,palette='RdBu_r')

# %%
sns.countplot(x='Outcome',hue='Age',data=data)

# %%
sns.distplot(data['DiabetesPedigreeFunction'].dropna(), kde=False, bins=30, color='Green')

# %%
data['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
data.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.372189  108.796036      67.993191      19.313122   68.792000
# 1           4.788613  140.613786      70.551912      22.173049  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        29.958600                  0.429734  31.841991
# 1        34.964945                  0.550500  37.435723

# %%
data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.089099       0.122399      -0.099514
# Glucose                      0.089099  1.000000       0.139863       0.072642
# BloodPressure                0.122399  0.139863       1.000000       0.207191
# SkinThickness               -0.099514  0.072642       0.207191       1.000000
# Insulin                     -0.096964  0.329784       0.089148       0.432670
# BMI                         -0.015430  0.179681       0.274645       0.381212
# DiabetesPedigreeFunction    -0.035988  0.124182       0.039959       0.183684
# Age                          0.461788  0.250379       0.231473      -0.126011
# Outcome                      0.194147  0.469506       0.062818       0.085366
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.096964 -0.015430                 -0.035988
# ...

# %%
sns.heatmap(data.corr(),yticklabels=True,cbar=True)

# %%
sns.countplot(x='Outcome', data=data,palette='hls')

# %%
table=pd.crosstab(data.Age,data.Outcome)
table.div(table.sum(1).astype(float),axis=0).plot(kind='bar',figsize=(16,6))

#sns.countplot(y='Age',data=data,palette='hls')

# %%
table=pd.crosstab(data.Pregnancies,data.Outcome)
table.div(table.sum(1).astype(float),axis=0).plot(kind='bar',figsize=(16,6))

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import warnings
warnings.filterwarnings("ignore")

# %%
data.Pregnancies[data.Pregnancies < 0] = 0

# %%
data.Pregnancies.describe()
# Out:
# count    742.000000
# mean       3.886358
# std        3.443762
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       17.000000
# Name: Pregnancies, dtype: float64

# %%
data.SkinThickness[data.SkinThickness<0]=0
data.BMI[data.BMI<0]=0
data.BloodPressure[data.BloodPressure<0]=0

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   742.000000  752.000000     768.000000     746.000000  768.000000
# mean      3.886358  119.966097      68.895389      20.358987   79.799479
# std       3.443762   32.367659      19.393614      15.898064  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  116.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.000000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  757.000000                768.000000  749.000000  768.000000
# mean    31.760712                  0.471876   33.761336    0.348958
# std      8.321469                  0.331329   12.297409    0.476951
# ...

# %%
data.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.392607  108.796036      67.993191      19.371732   68.792000
# 1           4.807138  140.613786      70.578595      22.204394  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.034855                  0.429734  31.841991
# 1        34.964945                  0.550500  37.435723

# %%
train,test=train_test_split(data, test_size=0.4)
train.shape
# Out:
# (460, 9)

# %%
test.shape
# Out:
# (308, 9)

# %%
test,check=train_test_split(test, test_size=0.5)

# %%
test.shape
# Out:
# (154, 9)

# %%
check.shape
# Out:
# (154, 9)

# %%
train.Pregnancies.describe()
# Out:
# count    442.000000
# mean       3.905022
# std        3.391341
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       17.000000
# Name: Pregnancies, dtype: float64

# %%
#chcking for null in Pregnancies
data.Pregnancies.isnull().sum()
# Out:
# 26

# %%
data.Pregnancies.mean()
# Out:
# 3.886358181740169

# %%
data.Pregnancies.fillna(value=3,inplace=True)

# %%
data.Pregnancies.isnull().sum()
# Out:
# 0

# %%
data.Glucose.describe()
# Out:
# count    752.000000
# mean     119.966097
# std       32.367659
# min        0.000000
# 25%       99.000000
# 50%      116.000000
# 75%      140.000000
# max      199.000000
# Name: Glucose, dtype: float64

# %%
data.Glucose.fillna(value=119.966097,inplace=True)

# %%
data.Glucose.isnull().sum()
# Out:
# 0

# %%
data.BloodPressure.describe()
# Out:
# count    768.000000
# mean      68.895389
# std       19.393614
# min        0.000000
# 25%       62.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64

# %%
sns.distplot(data.BloodPressure,kde=False,bins=10,color='Red')

# %%
data.BloodPressure[data.BloodPressure<20]=20

# %%
data.BloodPressure.describe()
# Out:
# count    768.000000
# mean      69.812874
# std       16.344725
# min       20.000000
# 25%       62.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64

# %%
data.SkinThickness.describe()
# Out:
# count    746.000000
# mean      20.358987
# std       15.898064
# min        0.000000
# 25%        0.000000
# 50%       23.000000
# 75%       32.000000
# max       99.000000
# Name: SkinThickness, dtype: float64

# %%
sns.distplot(data.SkinThickness.dropna(),kde=False,bins=60,color='Red')

# %%
data=data.round({'Pregnancies':0,'Glucose':1,'BloodPressure':2,'SkinThickness':1,'BMI':1,'DiabetesPedigreeFunction':3,'Age':1})

# %%
data.Insulin[data.Insulin>200]=200

# %%
data.Insulin.describe()
# Out:
# count    768.000000
# mean      65.217448
# std       75.534710
# min        0.000000
# 25%        0.000000
# 50%       30.500000
# 75%      127.250000
# max      200.000000
# Name: Insulin, dtype: float64

# %%
newframe=pd.read_csv('/home/nbuser/library/Pima_Indian_diabetes.csv')

# %%
data.Insulin=newframe.Insulin

# %%
data.Insulin[data.Insulin>300]=300

# %%
sns.distplot(data.Insulin,kde=False)

# %%
data.Insulin[data.Insulin==0]=72.8

# %%
sns.distplot(data.Insulin,kde=False)

# %%
data.Insulin.plot()

# %%
data.Insulin.interpolate().plot()

# %%
frame2 = data[['Insulin','Outcome']]

# %%
sns.countplot(x='Outcome',data=frame2,palette='hls')

# %%
data.BMI.describe()
# Out:
# count    757.000000
# mean      31.760634
# std        8.321653
# min        0.000000
# 25%       27.100000
# 50%       32.000000
# 75%       36.500000
# max       67.100000
# Name: BMI, dtype: float64

# %%
data.BMI.fillna(value=31.7,inplace=True)

# %%
sns.distplot(data.BMI,kde=False)

# %%
data.BMI[data.BMI==0]=data.BMI.mean()

# %%
sns.distplot(data.BMI,kde=False)

# %%
data.DiabetesPedigreeFunction.describe()
# Out:
# count    768.000000
# mean       0.471876
# std        0.331329
# min        0.078000
# 25%        0.243750
# 50%        0.372500
# 75%        0.626250
# max        2.420000
# Name: DiabetesPedigreeFunction, dtype: float64

# %%
sns.distplot(data.DiabetesPedigreeFunction)

# %%
data.Age.describe()
# Out:
# count    749.000000
# mean      33.760881
# std       12.296550
# min       21.000000
# 25%       24.000000
# 50%       29.000000
# 75%       41.000000
# max       81.000000
# Name: Age, dtype: float64

# %%
data.Age.isnull().sum()
# Out:
# 19

# %%
data.Age.fillna(value=33.7,inplace=True)

# %%
sns.distplot(data.Age)

# %%
data.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.376000  109.065000      68.762420      19.371811   98.911600
# 1           4.746269  140.306343      71.772612      22.204615  125.702985
#
#                BMI  DiabetesPedigreeFunction       Age
# Outcome
# 0        30.823634                  0.429734  31.87120
# 1        35.165371                  0.550500  37.28209

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
frame2 = data

# %%
train, test = train_test_split(data, test_size = 0.4)

# %%
train.shape
# Out:
# (460, 9)

# %%
test.shape
# Out:
# (308, 9)

# %%
train.isnull().sum()
# Out:
# Pregnancies                  0
# Glucose                      0
# BloodPressure                0
# SkinThickness               14
# Insulin                      0
# BMI                          0
# DiabetesPedigreeFunction     0
# Age                          0
# Outcome                      0
# dtype: int64

# %%
data.SkinThickness.fillna(value=data.SkinThickness.mean(),inplace=True)

# %%
train, test = train_test_split(data, test_size = 0.4)

# %%
scalar=StandardScaler()
train=scalar.fit_transform(train)

# %%
means = np.mean(train,axis=0)
stds = np.std(train,axis=0)

# %%
means
# Out:
# array([-7.91637287e-17,  3.74579594e-16, -4.24780983e-16,  7.33712608e-17,
#         1.04264423e-16,  9.46103099e-17,  0.00000000e+00,  2.54868590e-16,
#        -7.72329061e-17])

# %%
stds
# Out:
# array([1., 1., 1., 1., 1., 1., 1., 1., 1.])

# %%
train_x = train[:,train.columns!='Outcome']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-a729638a2b5f> in <module>()
# ----> 1 train_x = train[:,train.columns!='Outcome']
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
X_train, X_test, y_train, y_test = train_test_split(train.drop('Outcome',axis=1),train['Outcome'], test_size=0.30,)

# %%
X_train=scalar.fit_transform(X_train)

# %%
X_test = scalar.fit_transform(X_test)

# %%
#create an instance and fit the model
from sklearn.linear_model import LogisticRegression 
logmodel = LogisticRegression()
logmodel.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
prediction=logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,prediction))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.76      0.89      0.82       146
#           1       0.74      0.53      0.62        85
#
# avg / total       0.75      0.76      0.75       231

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, prediction))
# Out:
# [[130  16]
#  [ 40  45]]
